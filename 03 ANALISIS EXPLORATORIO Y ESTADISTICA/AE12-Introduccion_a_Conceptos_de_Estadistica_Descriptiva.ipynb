# %% [markdown]
# # **Análisis exploratorio y estadística**
#
# # AE12 - Introducción a Conceptos de Estadística Descriptiva

# %% [markdown]
# ## <font color='blue'>**Introducción**</font>
#
# ### **¿Qué es el Análisis Exploratorio de Datos?**
#
# El __Análisis Exploratorio de Datos__ o (__EDA__) consiste en una serie de técnicas y herramientas que nos permiten comprender los conjuntos de datos resumiendo sus características principales, a menudo graficándolos visualmente y utilizando descriptores estadisticos. Este paso es muy importante especialmente cuando llegamos a modelar los datos para aplicar el aprendizaje automático. La visualización en EDA consta de histogramas, boxplots, diagrama de dispersión y muchos más. A menudo se necesita mucho tiempo para explorar los datos. A través del proceso de EDA, podemos definir el enunciado del problema, desarrollar nuestras preguntas de investigación, realizar el diseño experimental, entre otrsa cosas.
#
# La **Estadística** es una disciplina científica que se ocupa de la obtención, ordenación  y análisis de un conjunto de datos con el fin de obtener explicaciones y predicciones sobre un fenómeno en estudio.

# %% [markdown]
# ## <font color='blue'>**Conceptos básicos**</font>
#
# **Población** : conjunto sobre el que estamos interesados en obtener conclusiones y  hacer inferencias.
#
# **Muestra** : subconjunto de la población, sobre la cual se harán las observaciones  o mediciones.
#
# **Variable**	: es una característica de un objeto o sujeto, que va variando entre los   diferentes individuos  de una población.
#
# **Dato** : valores que se obtienen al realizar un estudio estadístico.
#
# **Parámetro** : cantidad numérica que describe una característica de una Población.
#
# **Estadístico** : cantidad numérica que describe una característica de una Muestra.
#
# La **inferencia estadística** está basada en el estudio de las **muestras**. La muestra debe ser **representativa de la población** para poder extraer conclusiones válidas sobre la misma. La muestra debe ser **aleatoria**.

# %% [markdown]
# ### <font color='green'>Actividad 1</font>
#
# Se desea hacer un estudio de opinión a los alumnos de Enseñanza media de establecimientos municipales, sobre el reingreso a clases en el mes de Octubre del 2020, en la región metropolitana. Para ello se seleccionó de forma aleatoria a un grupo de  alumnos de cada establecimiento correspondiente al 10% de la matrícula del mes de Octubre. Las preguntas realizadas fueron:
#
# 1. En qué curso va actualmente.
# 2. De reanudarse las clases presenciales, ¿ud. se incorporaría?
# 3. ¿Cuántas horas a la semana tiene actualmente de clases online?
#
# Determine:
# 1. Población :
# 2. Muestra :
# 3. Variables:
# 4. Datos :

# %% [markdown]
# Respuestas: <font color='green'>Aquí ...</font>
#
# **Población:** La población de este estudio es los alumnos de Enseñanza media de establecimientos municipales de la Región Metropolitana
#
# **Muestra:** La muestra del estudio corresponde al 10% de la matrícula del mes de octubre de cada establecimiento
#
# **Variables:** Las variables del estudio son el curso (nivel), la disposición de si incorporarse o no a las clases presenciales  y la cantidad de horas de clase online a la semana
#
# **Datos:** Los datos del estudio son las respuestas de los estudiantes. Para la primera variable estos pueden ser I, II, III o IV medio. Para la segunda variable los datos pueden ser Sí o No. Para la tercera variable los datos son un número de horas, por ejemplo: 5, 10, 12, 20, etc.

# %% [markdown]
# <font color='green'>Fin actividad 1</font>

# %% [markdown]
# ## <font color='blue'>**Tipos de variables**</font>
# Es importante entender con qué tipo de data estamos trabajando y que tipo de distribución tienen. En un único dataset, podemos tener varios tipos simultáneamente.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1ojMS6TBe5auQSLoxC5ucwLaYalinkvAJ" width='900'>

# %% [markdown]
# ## <font color='blue'>**Medidas de Tendencia Central**</font>
#
# Las medidas de tendencia central son  valores que se encuentra hacia el centro de la distribución de los valores de una serie de observaciones.
#
# La **Moda** de una variable Cualitativa o Cuantitativa, es el valor que se presenta con mayor frecuencia en una distribución de datos.
#
# 1. Cuando __dos datos__ se presentan con la misma frecuencia y ésta es la más alta, ambos datos son moda, es decir,  la distribución es bimodal.
# 2. Cuando __dos o más datos__ se presentan con la misma frecuencia y esta es la más alta, todos datos son moda, es decir, la distribución es multimodal.
# 3. Cuando __todos los datos__ tienen la misma frecuencia, se dice que no hay moda.
#
# La **Mediana** de una variable cualitativa ordinal o cuantitativa, corresponde al valor intermedio, cuando los valores de la variable se presentan en orden de magnitud creciente (o decreciente).
#
#
# $$ Me = X_{\frac{n}{2}}, \mbox{  Para el caso que n es impar.}  $$
#
# $$ Me = \frac{X_{\frac{n}{2}} + X_{\frac{n}{2}+1}}{2},  \mbox{  Para el caso que n es par.}$$
#
# La **media aritmetica** de una variable cuantitativa, se calcula sumando los valores y dividiéndolos por el total de ellos.
#
# $$ Media = \frac{\sum X_i}{n}$$

# %% [markdown]
# ## <font color='blue'>**Medidas de dispersión**</font>
#
# <img src="https://drive.google.com/uc?export=view&id=1P287e7QaxbpEfGFE0JRq6uG_dbJWlA1E" width='800'>
#
#
# **Rango**: No es una medida significativa, pues solo indica cuán dispersos están los datos entre los extremos.
#
# $$R = X_{max} - X_{min}$$
#
# **Coeficiente de variación**: También llamado _Coeficiente de Variación de Pearson_, es una medida estadística que nos informa acerca de la dispersión relativa de un conjunto de datos. Es decir, nos informa, al igual que otras medidas de dispersión, si una variable se mueve mucho, poco, más o menos que otra. Se utiliza cuando se necesita comparar la dispersión de distribuciones de variables que tienen distintas unidades de medida.
#
# $$CV = \frac{S}{\bar{X}}$$
#
# Su fórmula expresa la desviación estándar como porcentaje de la media aritmética, mostrando una interpretación relativa del grado de variabilidad, independiente de la escala de la variable, a diferencia de la desviación típica o estándar. Por otro lado presenta problemas ya que a diferencia de la desviación típica este coeficiente es fuertemente sensible ante cambios de origen en la variable. Por ello es importante que todos los valores sean positivos y su media dé, por tanto, un valor positivo. A mayor valor del coeficiente de variación mayor heterogeneidad de los valores de la variable; y a menor C.V., mayor homogeneidad en los valores de la variable. Por ejemplo, si el C.V es menor o igual al 30%, significa que la media aritmética es representativa del conjunto de datos, por ende el conjunto de datos es "Homogéneo". Por el contrario, si el C.V supera al 30%, el promedio no será representativo del conjunto de datos (por lo que resultará "Heterogéneo"). Se calcula:
#
# Por ejempo, se quiere comprar la dispersión entre la altura de 50 alumnos de una clase y su peso. Para comparar la altura podríamos utilizar como unidad de medida metros y centímetros y para el peso el kilogramo. Comparar estas dos distribuciones mediante la desviación estándar, no tendría sentido dado que se pretenden medir dos variables cuantitativas distintas (una medida de longitud y una de masa).

# %% [markdown]
# ## <font color='blue'>**Medidas de posición**</font>
#
# **Cuartiles**  son medidas de posición  que dividen  la distribución ordenada en cuatro partes iguales, ellos son $Q_1 , Q_2 , Q_3 $.
#
# $Q_1$: ***Cuartil 1***. Es el valor de la variable que deja a la izquierda el 25% de los datos.
#
# **Rango intercuartilico (IQR)**: es una estimación estadística de dispersión  de una distribución de datos y corresponde a:
#
# $$IQR = Q_3-Q_1$$
#
# **Percentiles** son medidas de posición que dividen la distribución ordenada en 100 partes iguales, ellos son $P_1$, $P_2$, ..., $P_k$ , con $k=[1,99]$.
#
# $P_K$ :  ***Percentil k***. Es el valor de la variable que deja a la izquierda el $k\%$ de los datos.

# %% [markdown]
# ### <font color='green'>Actividad 2</font>
# ### Parámetros y estadísticos con Pandas
# Considere el data set  entregado state.csv. Calcule la media, la mediana, la desviacion estandar, coeficiente de variación y rango intercuartílico, para la variable Population.
# Imprima sus resultados.
#
# Tip: utilice la siguiente libreria
#
# ```
# import pandas as pd
# ```
#
# Explore en esta librería como calcular cada uno de los parámetros antes indicados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
import pandas as pd

path = "/content/drive/MyDrive/BITACORA - Grupo 3/03 ANALISIS EXPLORATORIO Y ESTADISTICA/Archivos/state.csv"

state = pd.read_csv(path)
state.head()
# Out:
#         State  Population  Murder.Rate Abbreviation
# 0     Alabama     4779736          5.7           AL
# 1      Alaska      710231          5.6           AK
# 2     Arizona     6392017          4.7           AZ
# 3    Arkansas     2915918          5.6           AR
# 4  California    37253956          4.4           CA

# %%
# Tu código aquí ...
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         50 non-null     object
#  1   Population    50 non-null     int64
#  2   Murder.Rate   50 non-null     float64
#  3   Abbreviation  50 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
# Tu código aquí ...
# media, la mediana, la desviacion estandar, coeficiente de variación y rango intercuartílico
mean = state['Population'].mean()
median = state['Population'].median()
ds = state['Population'].std()
CV = ds/mean
IQR = state['Population'].quantile(0.75)-state['Population'].quantile(0.25)

print(f'Media = {mean:0.0f}')
print(f'Mediana = {median:0.0f}')
print(f'Desviación estandar = {ds:0.0f}')
print(f'Coeficiente de variación = {CV*100:0.2f}%')
print(f'Rango intercuartil = {IQR:0.0f}')
# Out:
# Media = 6162876
# Mediana = 4436370
# Desviación estandar = 6848235
# Coeficiente de variación = 111.12%
# Rango intercuartil = 4847308

# %% [markdown]
# <font color='green'>Fin Actividad 2</font>

# %% [markdown]
# ## <font color='purple'> __EXPERIMENTO__: </font>
#
# ### Visualización gráfica de datos de población en estados de EEUU.
#
#
# Llama la atención que la desviasión estandar sea mayor que la media, y en consecuentcia que el coeficiente de variación sea mayor al 100%. Es por ello que se grafican un histograma y un diagrama de caja y bigotas para observar la distribución de los datos.
#
# De esta manera, es posible notar que la mayoría de los datos se encuentran bajo los 15 Millones de habitantes, con una mediana cercana a los 4,5 Millones, sin embargo existen cuatro outliers que elevan tanto la media como la desviasión estandar, que son California, Texas, New York y Florida.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
fig, ax = plt.subplots(1,2, figsize=(10,5))
sns.histplot(y='Population', data=state, ax = ax[0])
sns.boxplot(y='Population', data=state, ax = ax[1])
plt.show()
state.sort_values('Population', ascending=False).head()
# Out:
#          State  Population  Murder.Rate Abbreviation
# 4   California    37253956          4.4           CA
# 42       Texas    25145561          4.4           TX
# 31    New York    19378102          3.1           NY
# 8      Florida    18801310          5.8           FL
# 12    Illinois    12830632          5.3           IL

# %% [markdown]
# ### <font color='purple'>Fin experimento </font>

# %% [markdown]
# ## <font color='blue'>__Población__</font>
# Colección completa de todos los individuos de interés para el investigador.
#
# A continuación crearemos dos poblaciones; una con **Distribución Normal** (con media $\mu = 0$ y sigma $\sigma = 1$), y otra con **Distribución Uniforme**, para analizar sus parámetros.<br>
# Las distribuciones normales (o Gaussianas) se aplican a variables continuas, donde la gráfica de su función densidad de probabilidad tiene una forma acampanada y simétrica. Representan más del 50% de los fenomenos estudiados. Veremos más sobre distribuciones más adelante.

# %%
import numpy as np

# Generamos una semilla para que la población que creemos sea siempre la misma
np.random.seed(41)
# Generamos la población con la semilla creada
media = 0
sigma = 1.0
size = 10000

poblacion = np.random.normal(media, sigma, size)
poblacion[:10]
# Out:
# array([-0.27071232,  0.10484805,  0.25052782, -0.92519997,  0.56714366,
#        -1.04018022, -0.15367595,  0.78985181, -1.22621585, -0.94800699])

# %% [markdown]
# Ahora crearemos una segunda población con datos aleatorios con **Distribución Uniforme Discreta**, esta vez representando edades de 1000 adultos. Debemos hacerlo de la siguiente forma:
# ```Python
#     np.random.randint(valor_mínimo, valor_máximo, tamaño)
# ```

# %%
edad_min = 18 # rango inferior de edades
edad_max = 90 # rango superior de edades
size = 10000
edades = np.random.randint(low=edad_min, high=edad_max, size=size)
edades[:10] # Visualizamos los diez primeros
# Out:
# array([79, 18, 57, 21, 38, 88, 57, 35, 57, 20])

# %% [markdown]
# Si quisieramos crear una **Distribución Uniforme Continua** debemos hacerlo de esta forma:
#
# ```Python
#     np.random.uniform(valor_mínimo, valor_máximo, tamaño)
# ````

# %%
edades2 = np.random.uniform(low=edad_min, high=edad_max, size=size)
edades2[:10]
# Out:
# array([34.58394734, 57.3345976 , 35.59880407, 83.77787829, 72.93176306,
#        81.9808189 , 31.01013144, 35.86124183, 80.06157004, 70.63734344])

# %% [markdown]
# ### __Parámetros (poblacionales)__
# Dijimos que un *parámetro* es un valor que caractariza un aspecto de la población; e.g., media poblacional, mediana poblacional, desviación estándar poblacional, etc.
#
# Analicemos los parámetros de la población **poblacion**. Como los datos no están guardados en una estructura Pandas (Serie, DataFrame), utilizaremos las librerías _Nympy_ y _scipy_ para calcular parámetros y estadísticos.

# %%
print(f'Tamaño población\t\t= {len(poblacion):d} individuos')
print(f'Media poblacional\t\t= {poblacion.mean():4.2f}')
print(f'Desviación estándar poblacional\t= {poblacion.std():4.2f}')
print(f'Mediana poblacional\t\t= {np.median(poblacion):4.2f}')
# Out:
# Tamaño población		= 10000 individuos
# Media poblacional		= 0.00
# Desviación estándar poblacional	= 1.01
# Mediana poblacional		= 0.01

# %% [markdown]
# Ahora analicemos los parámetros de la población **edades**. Incorporamos una nueva medida, la __moda__. La moda es el valor que aparece con mayor frecuencia dentro de un conglomerado. En un grupo puede haber una única moda (`unimodal`), dos modas (`bimodal`), o más de dos modas (`multimodal`). Se llama a un grupo `amodal` cuando en él no se repiten los valores.
#
# Por último, se conoce como `moda adyacente` cuando dos valores continuos tienen la misma cantidad de repeticiones. En este caso se saca el promedio de ambos.

# %%
from scipy import stats # importando scipy.stats

print(f'Tamaño población edades\t\t\t= {len(edades):d} individuos')
print(f'Media de edades\t\t\t\t= {edades.mean():4.2f}')
print(f'Desviación estándar de las edades\t= {edades.std():4.2f}')
print(f'Mediana poblacional de las edades\t= {np.median(edades):4.2f}')
print(f'Moda poblacional es {stats.mode(edades, keepdims=True)[0][0]} y se repite {stats.mode(edades, keepdims=True)[1][0]} veces')
# Out:
# Tamaño población edades			= 10000 individuos
# Media de edades				= 53.45
# Desviación estándar de las edades	= 20.75
# Mediana poblacional de las edades	= 53.00
# Moda poblacional es 61 y se repite 164 veces

# %% [markdown]
# ## <font color='blue'>__Muestra__</font>
# Subconjunto aleatorio de la población, el cual es representativo de la misma.
#
# ### __Estadísticos (muestrales)__
# Medida descriptiva de la muestra que se utiliza para estimar al respectivo parámetro poblacional. El *estadístico* es básicamente lo mismo que el *parámetro poblacional*, pero se diferencia en que se calcula a partir de la muestra y no de la población. <br>
# La desviación estándar para muestras se denomina "__desviación estándar insesgada__" ya que se calcula dividiendo por $(n - 1)$. Investiga la [Corrección de Bessel](https://es.wikipedia.org/wiki/Correcci%C3%B3n_de_Bessel), para entender más de esto.
#
# **Observación**
#
# La desviación estándar muestral se denota con el símbolo: $S$ o $\widehat{\sigma}$
#
# La media muestral se denota con el símbolo: $\overline{X}$ o $\widehat{\mu}$

# %% [markdown]
# ### <font color='green'>Actividad 3</font>
# ### Parámetros y estadísticos con Numpy y scipy
# Realiza dos muestreos ( `muestra1` y `muestra2` ) a partir del dataset ___poblacion___. Para el primero de ellos selecciona los últimos 10 elementos del dataset, y para el segundo, realiza un muestreo aleatorio de 50 elementos.
# Calcula los estadísticos de ambas muestras y compáralos con los parámetros poblacionales.
# ¿Cuál de las dos muestras ( `muestra1` o `muestra2` ) es la mejor?
#
# Tip: para el muestreo aleatorio, utiliza:
# ```
# np.random.choice()
# ```

# %%
# Tu código aquí ...

## Copiamos el codigo que se encuentra más arriba donde se define población
# Generamos una semilla para que la población que creemos sea siempre la misma
np.random.seed(41)
# Generamos la población con la semilla creada
media = 0
sigma = 1.0
size = 10000

poblacion = np.random.normal(media, sigma, size)
poblacion[:10]


muestra1 = poblacion[-10:]
muestra2 = np.random.choice(poblacion, 100, replace=False)

print(f'La candidad de individuos son:')
print(f'Muestra 1 = {len(muestra1):4.0f}')
print(f'Muestra 2 = {len(muestra2):4.0f}')
print(f'Población = {len(poblacion):4.0f}')
print()
print(f'Los promedios son:')
print(f'Muestra 1 = {muestra1.mean():4.2f}')
print(f'Muestra 2 = {muestra2.mean():4.2f}')
print(f'Población = {poblacion.mean():4.2f}')
print()
print(f'Las medianas son:')
print(f'Muestra 1 = {np.median(muestra1):4.2f}')
print(f'Muestra 2 = {np.median(muestra2):4.2f}')
print(f'Población = {np.median(poblacion):4.2f}')
print()
print(f'Las desviaciones estandar son:')
print(f'Muestra 1 = {muestra1.std():4.2f}')
print(f'Muestra 2 = {muestra2.std():4.2f}')
print(f'Población = {poblacion.std():4.2f}')
# Out:
# La candidad de individuos son:
# Muestra 1 =   10
# Muestra 2 =  100
# Población = 10000
#
# Los promedios son:
# Muestra 1 = -0.18
# Muestra 2 = -0.07
# Población = 0.00
#
# Las medianas son:
# Muestra 1 = -0.13
# Muestra 2 = -0.06
# Población = 0.01
#
# Las desviaciones estandar son:
# Muestra 1 = 0.60
# Muestra 2 = 1.00
# Población = 1.01

# %% [markdown]
# Se observa que la muestra que da estadisticos más cercanos a los parametros de la población es aquella donde la cantidad de individuos es mayor. Tanto para el promedio como para la desviasión estandar. Cabe destacar, que en el caso de a primera muestra, donde se escogen los diez últimos individuos, esta muestra estará sesgada de manera que el resto de los individos tiene una probabilidad nula de salir en la muestra. En caso de desconocer si lsa muestra esta ordenada o no esta condición desemboca en un sesgo.

# %% [markdown]
# <font color='green'>Fin Actividad 3</font>

# %% [markdown]
# ## <font color='purple'> __EXPERIMENTO__: </font>
#
# ### Evauación y comparación de estadísticos para muestras de mayor tamaño de la población de la Actividad 3.

# %%
muestra3 = poblacion[-1000:]
muestra4 = np.random.choice(poblacion, 1000, replace=False)

print(f'La candidad de individuos son:')
print(f'Muestra 3 = {len(muestra3):4.0f}')
print(f'Muestra 4 = {len(muestra4):4.0f}')
print(f'Población = {len(poblacion):4.0f}')
print()
print(f'Los promedios son:')
print(f'Muestra 3 = {muestra3.mean():4.2f}')
print(f'Muestra 4 = {muestra4.mean():4.2f}')
print(f'Población = {poblacion.mean():4.2f}')
print()
print(f'Las medianas son:')
print(f'Muestra 3 = {np.median(muestra3):4.2f}')
print(f'Muestra 4 = {np.median(muestra4):4.2f}')
print(f'Población = {np.median(poblacion):4.2f}')
print()
print(f'Las desviaciones estandar son:')
print(f'Muestra 3 = {muestra3.std():4.2f}')
print(f'Muestra 4 = {muestra4.std():4.2f}')
print(f'Población = {poblacion.std():4.2f}')
# Out:
# La candidad de individuos son:
# Muestra 3 = 1000
# Muestra 4 = 1000
# Población = 10000
#
# Los promedios son:
# Muestra 3 = -0.04
# Muestra 4 = 0.09
# Población = 0.00
#
# Las medianas son:
# Muestra 3 = -0.07
# Muestra 4 = 0.05
# Población = 0.01
#
# Las desviaciones estandar son:
# Muestra 3 = 1.01
# Muestra 4 = 1.03
# Población = 1.01

# %% [markdown]
# En este caso, la muestra 3 se tomo como los últimos 1000 individuos de la población, mientras que la muestra 4 corresponde a 1000 individuos aleatorios. Se tiene que en el caso de promedio y la mediana, los estadísticos de la muestra 4 se encuentran más cercanos a los parámetros de la población, sin embargo en el caso de la desviación estandar, la muestra cuyo estadístico es más cercano al parámetro es la muestra 3. Para ambas muestras los estadísticos en general se encuentran más cercanos a los parámetros que en las muestras 1 y 2.
#
# Así, se demuestra que los estadísticos mejoran considerablemente con una muestra mayor, sin embargo se debe considerar los recursos que requiere tomar una muestra (ya sean monetarios,de tiempo u otros) para evaluar cuál es el tamaño de muestra ideal, que logre balancear una buena aproximación a los parámetros con un buen manejo de recursos.

# %% [markdown]
# ### <font color='purple'>Fin experimento </font>

# %% [markdown]
# ### __Error muestral__
# Es la diferencia entre el valor del **parámetro poblacional** y el producido por el **estadístico muestral**.
#
# Se concluye fácilmente que una buena técnica de muestreo reduce el error muestral del estimador.

# %%
print(f'Media población\t= {np.mean(poblacion):>5.3f}')
print(f'Media muestra1\t= {np.mean(muestra1):>5.3f}')
print(f'Media muestra2\t= {np.mean(muestra2):>5.3f}')
# Out:
# Media población	= 0.000
# Media muestra1	= -0.179
# Media muestra2	= -0.065

# %% [markdown]
# Grafiquemos el error muestral

# %%
import matplotlib.pyplot as plt

# %%
# Declara lista1 con 3 valores de medias
lista1 = [np.mean(poblacion), np.mean(muestra1), np.mean(muestra2)]
# Declara lista2 con 3 nombres
lista2 = ['Media Poblacional','Media Muestra 1','Media Muestra 2']
plt.figure(figsize=(10, 5))
plt.bar(lista2, lista1,
        color=['r','g','g'],
        alpha=0.5
       )   # Dibuja el gráfico
plt.title("Error muestral")   # Establece el título del gráfico
plt.xlabel("Grupo")   # Establece el título del eje x
plt.ylabel("Valor")   # Establece el título del eje y
plt.show()

# %% [markdown]
# Reflexiona sobre lo que ha ocurrido. Por qué los estadísticos muestrales son diferentes? Qué implicancias tiene el realizar un buen o un mal muestreo a partir de la población?

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Igtn9UXg6NGeRWsqh4hefQUjV0hmzlBv" width="100" align="left" title="Runa-perth">
# <br clear="left">
# Contenido opcional
#
# ## <font color='blue'>__Asimetría__</font>
#
# La __asimetría__ es una medida de la falta de simetría o sesgo en la distribución de un conjunto de datos. Una distribución es simétrica si se ve igual a ambos lados de su media.
#
# Tipos de Asimetría
#
# - __Asimetría o Sesgo Positivo (Derecha)__: Cuando la cola en el lado derecho de la distribución es más larga o más gruesa que la izquierda.
# - __Asimetría o Sesgo Negativo (Izquierda)__: Cuando la cola en el lado izquierdo de la distribución es más larga o más gruesa que la derecha.
# - Un valor de cero indica que no hay ningún sesgo en la distribución, lo que significa que la distribución es perfectamente simétrica, y que, por lo tanto, su media y mediana son iguales.
#
# <img src="https://drive.google.com/uc?export=view&id=1sHNxKTjFE32UHmjH4vAennEQjCd3tjE-" >

# %%
from scipy.stats import skew, norm, gamma, beta
import scipy.stats as stats

simetrica = norm.rvs(size=1000)
a = 1.99
derecha = gamma.rvs(a, size=1000)
a, b = 2.31, 0.627
izquierda = beta.rvs(a, b, size=1000)

print(f'Asimetría Positiva: {skew(derecha):.2f}')
print(f'Asimetría Negativa: {skew(izquierda):.2f}')
print(f'Siméttica: {skew(simetrica):.2f}')
# Out:
# Asimetría Positiva: 1.37
# Asimetría Negativa: -1.06
# Siméttica: 0.01

# %%
# Gráficos
import seaborn as sns
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
sns.histplot(derecha, bins=50, kde=True)
plt.title(f'Asimetría Positiva: {skew(derecha):.2f}')
plt.subplot(1, 3, 2)
sns.histplot(simetrica, bins=50, kde=True)
plt.title(f'Simétrica: {skew(simetrica):.2f}')
plt.subplot(1, 3, 3)
sns.histplot(izquierda, bins=50, kde=True)
plt.title(f'Asimetría Negativa: {skew(izquierda):.2f}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color='blue'>__Curtosis__</font>
#
# La curtosis es una medida de la "agudeza" de una distribución. Indica la cantidad de datos que están cerca de la media en comparación con una distribución normal.
#
# Tipos de Curtosis
#
# - __Leptocúrtica__: Distribución con colas más pesadas y un pico más agudo que la distribución normal. Curtosis > 0 (según definición de Fisher), o Cursosis > 3 (según definición de Pearson).
#
# - __Mesocúrtica__: Distribución con la misma forma que la distribución normal. Curtosis = 0 (según definición de Fisher), o Cursosis = 3 (según definición de Pearson).
#
# - __Platicúrtica__: Distribución con colas más ligeras y un pico más plano que la distribución normal. Curtosis < 0 (según definición de Fisher), o Cursosis < 3 (según definición de Pearson).
#
#
# <img src="https://drive.google.com/uc?export=view&id=1XbtCQSp7yFjJKmxVLWC2-vCIss0t5jHE" >

# %%
from scipy.stats import kurtosis, norm, uniform, laplace
import scipy.stats as stats

meso_data = norm.rvs(size=1000)
lepto_data = laplace.rvs(size=1000)
plati_data = uniform.rvs(size=1000,loc=-2, scale=4)

# Calcular curtosis
lepto_kurtosis = kurtosis(lepto_data, fisher=True)
plati_kurtosis = kurtosis(plati_data, fisher=True)
meso_kurtosis = kurtosis(meso_data, fisher=True)


print(f'Curtosis Leptocúrtica: {lepto_kurtosis:.2f}')
print(f'Curtosis Platicúrtica: {plati_kurtosis:.2f}')
print(f'Curtosis Mesocúrtica: {meso_kurtosis:.2f}')
# Out:
# Curtosis Leptocúrtica: 1.43
# Curtosis Platicúrtica: -1.18
# Curtosis Mesocúrtica: 0.05

# %%
# Veámoslo gráficamente
x = np.linspace(-5, 5, 100)
ax = plt.subplot()
dist_name = ['laplace', 'norm', 'uniform']
for d in dist_name:
    if d == 'uniform':
        dist = getattr(stats, d)(loc=-2, scale=4)
    else:
        dist = getattr(stats, d)
    data = dist.rvs(size=1000)
    kur = kurtosis(data, fisher=True)
    y = dist.pdf(x)
    ax.plot(x, y, label=f"{d}, {kur: 4.2f}")
    ax.legend()

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Igtn9UXg6NGeRWsqh4hefQUjV0hmzlBv" width="50" align="left" title="Runa-perth">

# %% [markdown]
# ### <font color='red'>__LINK DE INTERÉS__: Material adicional de Asimetría y Curtosis</font>
# Se presenta material complementario sobre asimetría y curtosis en el siguiente link [aquí](https://www.datacamp.com/es/tutorial/understanding-skewness-and-kurtosis).

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1DNuGbS1i-9it4Nyr3ZMncQz9cRhs2eJr" width="100" align="left" title="Runa-perth">
# <br clear="left">
#
# ## <font color='blue'>**Resumen**</font>
#
# ### __Estadística Descriptiva__
#
# La estadística descriptiva se utiliza para describir, resumir y entender las características básicas de un conjunto de datos, sin hacer inferencias a partir de él.
#
# __Conceptos Básicos__
#
# - __Población__
# La población se refiere al conjunto completo de elementos o casos que se están estudiando.
# - __Muestra__
# Una muestra es un subconjunto de la población.
# - __Variable__
# Una variable es cualquier característica que pueda variar y se pueda medir en una población.
# - __Dato__
# Un dato es una observación o medida de una variable.
#
# __Medidas de Centralidad__
#
# - __Media__
# La media es el promedio de un conjunto de datos.
# - __Mediana__
# La mediana es el valor que separa un conjunto de datos en dos partes iguales.
# - __Moda__
# La moda es el valor que aparece con mayor frecuencia en un conjunto de datos.
#
# __Medidas de Dispersión__
#
# - __Rango__
# El rango es la diferencia entre el valor máximo y el valor mínimo de un conjunto de datos.
# - __Varianza__
# La varianza es el promedio de las diferencias al cuadrado entre cada dato y la media.
# - __Desviación Estándar__
# La desviación estándar es la raíz cuadrada de la varianza.
#
# __Medidas de Posición__
#
# - __Cuartiles__
# Los cuartiles dividen un conjunto de datos en cuatro partes iguales.
# - __Percentiles__
# Los percentiles dividen un conjunto de datos en cien partes iguales.
#
# __Error__
#
# - __Error Estándar__
# El error estándar es una medida de la variabilidad de la media muestral.
# - __Error Absoluto__
# El error absoluto es la diferencia entre el valor observado y el valor verdadero.
# - __Error Relativo__
# El error relativo es el error absoluto dividido por el valor verdadero.
#
# __Otros Conceptos__
#
# - __Asimetría__
# La asimetría es una medida de la falta de simetría en la distribución de un conjunto de datos.
# - __Curtosis__
# La curtosis es una medida de la "agudeza" de una distribución.
#
# <img src="https://drive.google.com/uc?export=view&id=1DNuGbS1i-9it4Nyr3ZMncQz9cRhs2eJr" width="50" align="left" title="Runa-perth">
# <br clear="left">
