# %% [markdown]
# # <b>MODULO SQL</b>
#
# ## Profesores:
#
# - Andres Ramos  (andres.ramosm.ing@ingenieros.udd.cl)
# - Jennifer Paredes (jenniffer.paredes.ing@ingenieros.udd.cl)

# %% [markdown]
# ## <b>Syllabus</b>
#
# - Introducción a las bases de datos (Fuentes Abiertas de datos, BD Relacionales)
# - SQL (Definición y Operaciones), SQLite
# - SQL y operaciones condicionales, Agregación, Agrupamientos, Ordenamientos
# - SQL Joins (Inner, Outer, Left, Right, Cross)
# - SQL Consultas Anidadas
# - Modelamiento de una BD (Modelo Entidad-Relación y Modelo Relacional)
# - SQL Union, Intersect, Except.
# - SQL Triggers Operación Insert, Update y Delete.

# %% [markdown]
# ## <b>Texto de consulta</b>
# ![sqlBook.png](data:image/png;base64,...)

# %% [markdown]
# ## <b> Evaluaciones</b>
#
# ### Bitácora Grupal:
#
# La **Bitácora Grupal** es la herramienta de evaluación de este curso. La misma estará conformada por todos los **Notebooks** de cada una de las clases y módulos del curso. Los grupos de trabajo deben desarrollarla de forma colaborativa y creativa.
#
# Los aspectos a evaluar de la Rúbrica de la **Bitácora Grupal** y de los **Notebooks** que la componen, son los siguientes:
# * Orden.
# * Ejercicios y tareas.
# * Reflexión grupal.
# * Contenidos adicionales.
#
# Los detalles se encuentran en la Rúbrica publicada en Miro.
#
# ### Proyecto:
#
# El **Proyecto** de este curso se va a desarrollar en horario de clases, de forma grupal y consistirá en la aplicación de todos los contenidos del curso presentados en el syllabus. Partiendo desde el modelamiento y creación de una base de datos, hasta mostrar el manejo de las cláusulas utilizando filtrados condicionales, agrupamientos y agregaciones, Joins y otro tipo de uniones, consultas anidadas y definir triggers.
#
# ### Casos de Uso
# Uno por cada integrante del grupo (todos en un sólo notebook).
#
# ### Autoevaluación y Coevaluación
# La autoevaluación incluye una apreciación del profesor.

# %% [markdown]
# ## <b>Acuerdos</b>
#
# Como recordatorio:
#
# <center><img src="https://drive.google.com/uc?id=1WV--ikmlMLCTGIIisLMFmCmSScW-qryM"></center>
#
# Insistimos en:
#
# - Tener siempre la cámara prendida.
# - Preguntar!.
# - Auto organizarse en los trabajos grupales y que nadie se reste.
#
# Si existen dudas respecto al material al momento de ir estudiando los notebooks, **contáctennos por correo**.
